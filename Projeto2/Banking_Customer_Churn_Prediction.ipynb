# %% [markdown]
# # Artificial Intelligence - Supervised Learning
#
# ## *Banking Customer Churn Prediction*
#
# ![Alt Text](img/ML_banking.png)
#
# #### This project was made by:
# - `João Alves - up202108670@up.pt`
# - `Alberto Serra - up202103627@up.pt`
# - `Eduardo Sousa - up202103342@up.pt`
#
# ## Introduction
#
# ### About the Dataset
# The dataset used in this project is the "Banking Customer Churn Prediction Dataset," which is commonly utilized in the banking sector to predict customer retention. This dataset comprises 10,000 observations with 14 attributes, including customer demographics (e.g., age, geography, gender), account details (e.g., balance, number of products), and the target variable Exited. The Exited attribute is a binary variable indicating whether a customer has left the bank (1) or stayed (0). Understanding patterns in this dataset can help in predicting customer churn, which is important for maintaining profitability in the banking sector.
#
# - **Comprehensive Customer Insights**: The dataset not only provides a snapshot of customer information but also offers valuable insights into customer behavior patterns.
# - **Attribute Significance**: Attributes such as CreditScore, Geography, and Gender are pivotal in understanding the segmentation of the customer base.
# - **Predictive Analytics**: Ideal for applying various machine learning techniques to identify significant predictors of customer churn, enabling the development of targeted retention strategies.
#
# ### About the Problem
# Customer churn, or the tendency of customers to cease doing business with a company, is a significant concern for any commercial entity, especially in the banking industry where acquiring a new customer can be considerably more expensive than retaining an existing one. The problem addressed in this project is to predict whether a customer will leave the bank based on their historical data. This is a binary classification problem, where we aim to classify customers into one of two categories: will churn or will not churn.
#
# - **Behavioral Complexity**: The challenge of predicting customer churn lies in the complexity of human behavior and the numerous factors influencing a customer's decision to leave.
# - **Influential Factors**: Factors such as customer satisfaction, service quality, competitive offers, and personal circumstances play crucial roles.
# - **Advanced Analytics**: Leveraging advanced machine learning algorithms can uncover patterns and trends that traditional statistical methods might overlook.
#
# ### About the Solution
# To tackle the problem of predicting customer churn, we will employ several supervised machine learning techniques. We'll start by conducting an exploratory data analysis to gain insights into the data and identify any underlying patterns or anomalies. Following this, we will preprocess the data, including handling missing values, encoding categorical variables, and normalizing data as required. We will then construct and train at least three different predictive models using algorithms. Each model will be evaluated based on its accuracy and precision. The final step will involve comparing these models to determine the most effective approach for predicting customer churn. By the end of this project, we aim to develop a robust model that the bank can use to predict and mitigate customer churn effectively.
#
# - **Diverse Algorithm Implementation**: Machine learning models will range from simple logistic regression to complex ensemble methods like Random Forest and Gradient Boosting.
# - **Neural Network Exploration**: Exploring neural networks to capture non-linear relationships in the data.
# - **Performance Evaluation**: Rigorous evaluation using metrics such as precision, recall, and F1-score curve to ensure reliability and robustness.
# - **Cross-Validation**: Use of k-fold cross-validation to provide an unbiased estimate of model performance, strengthening model selection and validation.
#
# ---

# %% [markdown]
# ### Data Collection & Imported Libraries
#
# The quality and organization of the current dataset will determine the study that follows. We are using the "Banking Customer Churn Prediction Dataset" for this research, which contains a variety of customer characteristics along with their churn status. This dataset is essential in identifying critical elements that impact customer retention in the banking industry and will form the basis for all predictive modeling endeavors. A pandas DataFrame, which offers an adaptable framework for data manipulation and analysis, is filled with the data. To verify integrity and a successful import, the first few records in the dataset are displayed during the initial examination.

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from IPython.display import display
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_val_score, KFold
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# #### Importance of Data Integrity and Library Functionality
#
# - **Dataset Integrity**: Ensuring the dataset is complete and accurate is critical for reliable analysis. Initial checks for missing values, duplicate entries, and data types are essential steps in data validation.
# - **Library Imports**: The libraries imported here form the backbone of our data analysis and machine learning pipeline. Each library has a specific role:
#   - `pandas`: For data manipulation and analysis.
#   - `seaborn` and `matplotlib.pyplot`: For data visualization.
#   - `sklearn.preprocessing`: For preprocessing steps like encoding and scaling.
#   - `sklearn.metrics`: For model evaluation metrics and confusion matrix display.
#   - `sklearn.linear_model`, `sklearn.ensemble`, `sklearn.svm`, `sklearn.tree`, `sklearn.neighbors`, `sklearn.naive_bayes`, `sklearn.neural_network`, `sklearn.discriminant_analysis`: For various machine learning algorithms.
#   - `xgboost` and `catboost`: For advanced gradient boosting algorithms.
#   - `IPython.display`: For displaying dataframes and visualizations within the notebook.
#
# #### Library Functionality and Their Roles
#
# - **Data Manipulation**: `pandas` is used for data cleaning, transformation, and organization into a DataFrame.
# - **Visualization**: `seaborn` and `matplotlib.pyplot` enable us to create detailed plots for exploratory data analysis and to visualize the performance of our models.
# - **Preprocessing**: `LabelEncoder` and `StandardScaler` from `sklearn.preprocessing` are used to convert categorical variables into numerical format and to normalize feature values, respectively.
# - **Model Evaluation**: `confusion_matrix` and `ConfusionMatrixDisplay` provide insights into model performance by showing the accuracy of predictions.
# - **Machine Learning Models**: Various classifiers from `sklearn` and boosting algorithms from `xgboost` and `catboost` are utilized to train and predict customer churn. These models include logistic regression, decision trees, random forests, support vector machines, k-nearest neighbors, naive Bayes, neural networks, and discriminant analysis.
# - **Model Selection**: `cross_val_score` and `KFold` from `sklearn.model_selection` are used for cross-validation, ensuring our model's performance is robust and generalizes well to unseen data.
#
# By comprehensively understanding and utilizing these libraries, we can effectively preprocess our data, build predictive models, and evaluate their performance to tackle the problem of customer churn in the banking sector.
#
# **Take in consideration that re-running the code in this notebook might take around an hour to complete.**

# %% [markdown]
# #### Creating a dataframe with CSV dataset given
#
# Loading data into a DataFrame is a crucial step in data analysis, providing a structured way to manipulate and analyze data efficiently. In this section, we load the dataset into a pandas DataFrame and display the first few rows to ensure that the data has been loaded correctly.

# %%
# Load the dataset
file_path = 'Churn_Modelling.csv'
churn_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to verify successful loading
print("First few rows of the dataframe:\n")
display(churn_data.head())
# Out:
# First few rows of the dataframe:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# ...

# %% [markdown]
# #### Importance of Initial Data Loading
# - **Data Integrity Verification**: Ensures the dataset is correctly imported without issues such as missing files or corrupted data.
# - **Data Familiarization**: Provides an immediate understanding of the dataset's structure and content, including feature types and initial value distributions.
# - **Readiness for Preprocessing**: Prepares for subsequent data preprocessing steps, such as handling missing values, encoding categorical variables, and scaling numerical features.

# %% [markdown]
# ---
#
# # Data Preprocessing
#
# Prior to deploying machine learning algorithms, our dataset requires thorough preprocessing to ensure its quality. This crucial phase involves a series of steps aimed at refining the data:
#
# 1. **Handling Missing Data**: We ascertain the completeness of the dataset by identifying and addressing any missing values.
# 2. **Removing Irrelevant Features**: Certain features that do not contribute to the model's predictive capability, such as identifiers and unique customer information, are removed.
# 3. **Correcting Erroneous Entries**: We analyze the dataset for any improbable or incorrect entries, especially within key features like 'EstimatedSalary', and rectify them accordingly.
# 4. **Encoding Categorical Variables**: Categorical data is transformed into a numerical format via encoding techniques, rendering it suitable for machine learning algorithms.
# 5. **Normalizing Numerical Features**: To ensure all numerical features contribute equally to the model's predictions, we apply normalization or standardization techniques to scale the data.
# 6. **Exporting the Clean Data**: The final step involves saving the processed data to a new CSV file, which will be used in subsequent stages of model training and evaluation.
#
# The diligent application of these preprocessing steps is critical to mitigate the risk of bias or errors, which could otherwise lead to misguiding predictions and insights.

# %% [markdown]
# ### Dataset Basic Statistics
#
# The descriptive statistics below provide a snapshot of the dataset's numerical features. These statistics are foundational for understanding the range, central tendency, and distribution of the data we are working with. Such insights can inform preprocessing decisions like normalization or feature scaling.

# %%
# Displaying basic statistics for numerical features to gain initial insights

print("Dataset Basic Statistics:\n")
display(churn_data.describe())
# Out:
# Dataset Basic Statistics:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# This bar plot demonstrates the distribution of the dataset's target variable: churn status. An understanding of the balance between churned and non-churned customers is crucial as it can greatly affect the performance of the predictive model and may necessitate techniques like class weighting or resampling.
#
# ##### Insights from Class Distribution Plot
#
# - **Imbalanced Dataset**: The pie chart reveals a significant class imbalance, with approximately 79.6% of customers retained and only 20.4% having exited. This imbalance can affect model performance, particularly if accuracy is the sole metric used for evaluation, as the model might be biased towards the majority class.
# - **Implications for Model Training**: Given the imbalance, it is crucial to consider techniques such as resampling (oversampling the minority class or undersampling the majority class) or using algorithms that can handle class imbalance effectively, such as cost-sensitive learning or ensemble methods.
# - **Performance Metrics**: When evaluating model performance, it is important to use metrics that account for class imbalance, such as precision, recall, and F1 score rather than relying solely on accuracy.
# - **Business Context**: Understanding the churn rate (20.4% in this case) provides valuable context for the business. It indicates the proportion of customers who have left, which can help in strategizing retention efforts and identifying at-risk customers for targeted interventions.

# %%
# Visualizing the class distribution as a pie chart

print("Class Distribution (Churn vs. Non-Churn):\n")
churn_distribution = churn_data['Exited'].value_counts()
labels = 'Retained', 'Exited'
colors = ['purple', 'yellow']
fig, ax = plt.subplots()
fig.patch.set_facecolor('white')
ax.set_facecolor('white')
plt.pie(churn_distribution, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Percentage of Customers Exited and Retained')
plt.show()
# Out:
# Class Distribution (Churn vs. Non-Churn):

# %% [markdown]
# ##### Importance of Basic Statistical Analysis
#
# - **Initial Data Insights**: Provides an overview of the central tendency, dispersion, and shape of the dataset's distribution.
# - **Detecting Anomalies**: Helps identify outliers and unusual patterns that might affect model performance.
# - **Feature Understanding**: Enhances understanding of each feature's role and its potential impact on the target variable.
# - **Guiding Preprocessing**: Informs preprocessing decisions such as normalization, scaling, and handling missing values.

# %% [markdown]
# #### Missing data
#
# - **Data Completeness**: Checking for missing data is crucial as it ensures the dataset is complete, which is essential for reliable analysis and modeling. Missing values can lead to biased results and misinterpretation if not handled properly.
# - **Impact on Model Performance**: The presence of missing data can significantly affect model performance. Models may not learn effectively from incomplete data, leading to lower predictive accuracy and generalization.
# - **Strategies for Handling Missing Data**:
#   - **Deletion**: Removing rows or columns with missing values if they are few and not critical.
#   - **Imputation**: Replacing missing values with mean, median, mode, or using advanced methods like K-nearest neighbors (KNN) or regression techniques.
#   - **Indicator Variables**: Creating additional binary variables indicating the presence of missing values, which can sometimes provide useful information.
# - **Verification of Data Integrity**: Confirming the absence of missing values, as in this dataset, simplifies the preprocessing steps and enhances confidence in subsequent analysis and modeling efforts. Our dataset has zero missing values, thus eliminating the need for complex imputation methods and further simplifying the preprocessing stage.

# %%
# Checking for missing values to identify if any data imputation or cleaning is necessary

print("Missing Values Check:\n")
display(churn_data.isnull().sum())
# Out:
# Missing Values Check:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Before delving deeper into the data, it is imperative to check for missing values. The presence of missing data can lead to biased models if not handled properly. The output above confirms that our dataset is free from missing values, thus simplifying the preprocessing stage. This ensures data integrity and eliminates the need for complex imputation methods, thereby streamlining the preprocessing process.

# %% [markdown]
# #### Irrelevant Fields
#
# Some features in the dataset, such as "RowNumber", "CustomerId", and "Surname", do not contribute to the predictive power of our churn model. These identifiers are unique to each customer and hold no generalizable pattern that could aid in prediction. As a result, we will remove these columns from the dataset.
#
# **Reasons for Removing Irrelevant Fields:**
#
# - **Uniqueness of Identifiers**: Features like "RowNumber", "CustomerId", and "Surname" are unique identifiers for each record. They do not provide any useful information for predicting customer churn.
# - **Noise Reduction**: Including irrelevant fields can introduce noise, potentially leading to overfitting and reduced model generalizability.
# - **Simplifying the Model**: Removing non-contributory fields simplifies the model, making it more interpretable and efficient, focusing on impactful features.
# - **Enhanced Performance**: Eliminating unnecessary columns improves the computational efficiency of the model training process, allowing for faster training times and potentially better performance.

# %%
# Make sure 'Exited' is a categorical type for better color mapping
churn_data['Exited'] = churn_data['Exited'].astype('category')

# Dropping the irrelevant columns
churn_data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %% [markdown]
# ### Addressing Erroneous Salary Entries
#
# The "EstimatedSalary" feature may contain erroneously entered values that could distort our analysis. Specifically, entries below a reasonable threshold for annual salary are considered incorrect and will be removed from the dataset. Additionally, extremely low salary values, though above the incorrect threshold, will be classified as outliers and inspected further.
#
# **Rationale for Addressing Erroneous Salary Entries:**
#
# 1. **Ensuring Data Integrity**: Salaries below a plausible threshold of $1000 are likely input errors or misrepresentations, and including them could lead to inaccurate model predictions. By removing these entries, we ensure the integrity of our dataset.
# 2. **Identifying Outliers**: Entries with estimated salaries below $5000 but above $1000 are identified as potential outliers. These values may represent edge cases or specific scenarios that warrant further inspection. This step helps in understanding the variability in salary data and its impact on churn prediction.
# 3. **Improving Model Accuracy**: Removing implausible salary entries helps in reducing noise in the data, leading to more accurate and reliable predictions. This is crucial for building a robust churn prediction model.
# 4. **Streamlining Data Analysis**: By focusing on a realistic range of salary values, we streamline the data analysis process, making it easier to draw meaningful insights and conclusions.

# %%
# Removing rows where the estimated salary is below the threshold of plausibility
# Identifying outliers in the 'EstimatedSalary' feature

churn_data = churn_data[churn_data['EstimatedSalary'] >= 1000]
salary_outliers = churn_data[(churn_data['EstimatedSalary'] < 5000) & (churn_data['EstimatedSalary'] >= 1000)]
print("Potential outliers based on salary:")
print(salary_outliers[['EstimatedSalary']])
# Out:
# Potential outliers based on salary:
#       EstimatedSalary
# 58            1643.11
# 84            1907.66
# 223           4861.72
# 337           2010.98
# 361           2319.96
# ...               ...
# 9863          3497.43
# 9928          2444.29
# 9954          3449.22
# 9979          2988.28
# 9987          1914.41
#
# [205 rows x 1 columns]

# %% [markdown]
# #### Saving the Cleaned Dataset
#
# After performing the necessary data preparing, we save the refined dataset to a new CSV file. This file will be utilized for training and testing our machine learning models, ensuring that they learn from quality, error-free data.
#
# **Importance of Saving the Cleaned Dataset:**
#
# 1. **Consistency in Analysis**: By saving the cleaned dataset, we ensure that the same data is used across different stages of the project. This consistency is crucial for reproducibility and reliability in machine learning experiments.
# 2. **Efficient Workflow**: Storing the preprocessed data allows for efficient workflow management. Subsequent analyses and model training can proceed without the need to repeat data cleaning steps, saving time and computational resources.
# 3. **Error-Free Data for Modeling**: Ensuring the dataset is free from errors and inconsistencies is critical for model performance. Cleaned data helps in building more accurate and robust predictive models.
# 4. **Facilitating Collaboration**: Saving the cleaned dataset in a standardized format (CSV) facilitates collaboration among team members. It allows different stakeholders to access and utilize the same version of the dataset, enhancing coordination and productivity.

# %%
# Saving the cleaned and preprocessed data to a new CSV file

cleaned_file_path = 'cleaned_churn_data.csv'
churn_data.to_csv(cleaned_file_path, index=False)
print(f"Cleaned data saved to '{cleaned_file_path}'")
# Out:
# Cleaned data saved to 'cleaned_churn_data.csv'

# %% [markdown]
# ---

# %% [markdown]
# # Data Analysis
#
# After preprocessing the data, visualizing the refined dataset allows us to confirm the effectiveness of our cleaning and transformation steps. These visualizations can provide insights into the distribution and relationships of the cleaned data compared to the original. We will recreate some of the initial visualizations to highlight differences and to ensure that the data now conforms more closely to the assumptions of our analytical models.

# %% [markdown]
# #### Exploring Pairwise Relationships
#
# The pairplot below offers a detailed visualization of the relationships between pairs of variables, now enhanced with color coding to distinguish between churned and non-churned customers. This color distinction is achieved by setting the 'hue' parameter, which assigns different colors to the classes within the 'Exited' category, thereby facilitating a more intuitive analysis of clusters and patterns. By observing how the variables interact with the churn status across the different plots, we can hypothesize potential predictive relationships. Trends or groupings differentiated by color in this plot can suggest influential interactions between variables that are associated with the likelihood of customer churn.

# %%
# Exploring Pairwise Relationships

churn_data['Exited'] = churn_data['Exited'].astype('category')
sns.pairplot(churn_data.sample(500), hue='Exited', palette='bright')
plt.show()

# %% [markdown]
# ##### Insights from Pairwise Relationships
#
# - **Credit Score**: Higher credit scores do not show a significant separation between exited and retained customers, indicating that credit score alone may not be a strong predictor of churn.
# - **Age**: There is a noticeable cluster of older customers who are more likely to churn. This suggests age as a potential factor in predicting customer churn.
# - **Balance**: Customers with higher account balances tend to have a more varied churn rate, indicating that balance might interact with other factors to influence churn.
# - **Number of Products**: The distribution suggests that customers with fewer products are more likely to churn, highlighting cross-selling opportunities as a retention strategy.
# - **Tenure**: The tenure variable shows some separation, suggesting that customers with very low or very high tenure might have different churn rates, which could be indicative of either new customers or those losing interest over time.
# - **Estimated Salary**: Salary does not appear to have a clear pattern with churn, suggesting it may have less impact compared to other variables.
#
# These insights can guide further feature engineering and model development by emphasizing the variables that show significant interaction with churn status.

# %% [markdown]
# #### Distribution of Numerical Features Post-Processing
#
# By observing the distributions of the standardized numerical features, we can evaluate the scaling's impact and ensure that features are on a comparable scale, which is crucial for many machine learning algorithms that are sensitive to the scale of input data.

# %%
# Count column plots to map the dependence of 'Exited' column on categorical features

fig, ax = plt.subplots(2, 3, figsize=(30, 15))
sns.countplot(x='Geography', hue='Exited', data=churn_data, palette='Set2', ax=ax[0][0])
sns.countplot(x='Gender', hue='Exited', data=churn_data, palette='Set2', ax=ax[0][1])
sns.countplot(x='HasCrCard', hue='Exited', data=churn_data, palette='Set2', ax=ax[0][2])
sns.countplot(x='IsActiveMember', hue='Exited', data=churn_data, palette='Set2', ax=ax[1][0])
sns.countplot(x='NumOfProducts', hue='Exited', data=churn_data, palette='Set2', ax=ax[1][1])
sns.countplot(x='Tenure', hue='Exited', data=churn_data, palette='Set2', ax=ax[1][2])
plt.show()

# %% [markdown]
# - **Geography**: Higher churn in Germany compared to France and Spain.
# - **Gender**: Higher churn among female customers.
# - **HasCrCard**: Higher retention for customers with credit cards.
# - **IsActiveMember**: Lower churn for active members.
# - **NumOfProducts**: Higher churn with one product; lower with two products.
# - **Tenure**: No strong churn trend, indicating lesser predictive significance.

# %% [markdown]
# ##### Importance of Visualizing Post-Processed Numerical Features
#
# - **Comparability Across Features**: Standardizing numerical features ensures equal contribution to the model's performance. For instance, features like 'Balance' and 'EstimatedSalary' have been scaled to prevent disproportionate influence.
#
# - **Identification of Patterns and Relationships**: Visualization helps identify residual patterns or relationships between features and the target variable. For example, 'Geography' and 'Gender' show distinct churn patterns, suggesting predictive relationships.
#
# - **Verification of Data Integrity**: Consistent distributions across features validate preprocessing steps and confirm data integrity. Our plots indicate successful standardization.
#
# - **Detection of Outliers**: Standardized visualizations highlight outliers, as seen in 'EstimatedSalary', warranting further investigation.
#
# - **Improvement of Model Performance**: Balanced features enhance model convergence and performance, particularly for gradient-based algorithms.
#
# By incorporating these visual assessments, we can enhance our understanding of the data and ensure that our machine learning models are built on a solid foundation of well-preprocessed input features.

# %% [markdown]
# ### Correlation Heatmap of Processed Data
#
# A correlation heatmap provides a succinct and visual representation of the strength and direction of linear relationships between pairs of features. It's particularly useful for quickly identifying features that may have a strong predictive relationship with the target variable ('Exited'), which is our main interest in predicting customer churn. High positive or negative values indicate potential predictors for our model, whereas values near zero suggest little linear correlation. The heatmap also helps in detecting multicollinearity among predictors, where high correlations between independent features can affect the accuracy of linear regression models.

# %%
# Visualizing the correlation matrix using a heatmap
numerical_columns = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary']
plt.figure(figsize=(10,10))
corr_matrix = churn_data[numerical_columns + ['Exited']].corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##### Analysis of Correlation Heatmap
#
# The correlation heatmap of our processed data reveals several key insights:
#
# - **CreditScore and Age**: These features show very low correlation with the target variable 'Exited' as well as with other features. This indicates they may not be strong predictors of churn individually.
# - **Balance and NumOfProducts**: There is a noticeable negative correlation (-0.3) between 'Balance' and 'NumOfProducts'. This suggests that as the balance increases, the number of products tends to decrease, which could imply customers with higher balances are satisfied with fewer products.
# - **Balance and Tenure**: The correlation between 'Balance' and 'Tenure' is very low (-0.012), indicating that how long a customer has been with the bank does not strongly influence their account balance.
# - **NumOfProducts and Tenure**: The very low correlation (0.013) suggests that the number of products a customer holds does not significantly relate to their tenure.
# - **EstimatedSalary**: This feature shows low correlation with 'Exited' and with other features, implying it may not significantly impact churn prediction.
#
# These insights help in understanding which features might be more influential in predicting customer churn and in ensuring the model's robustness by addressing multicollinearity.

# %% [markdown]
# #### Box Plots for Comparative Analysis
#
# Box plots across different categories of a categorical variable like geography provide a visual comparison of how numerical attributes distribute across these categories. By examining features like 'Age', 'Balance', and 'CreditScore' across different geographies, we can deduce if regional factors contribute to churn. These plots highlight medians, quartiles, and any potential outliers, allowing us to see whether certain regions exhibit unique characteristics that might influence customer behavior and churn rates.

# %%
# Count column plots to map the dependence of 'Exited' column on continuous and numerical features

fig, ax = plt.subplots(2, 3, figsize=(30, 15))
sns.boxplot(data=churn_data, x='Exited', y='CreditScore', hue='Exited', ax=ax[0][0])
sns.boxplot(data=churn_data, x='Exited', y='Age', hue='Exited', ax=ax[0][1])
sns.boxplot(data=churn_data, x='Exited', y='Balance', hue='Exited', ax=ax[0][2])
sns.boxplot(data=churn_data, x='Exited', y='EstimatedSalary', hue='Exited', ax=ax[1][0])
sns.boxplot(data=churn_data, x='Exited', y='NumOfProducts', hue='Exited', ax=ax[1][1])
sns.boxplot(data=churn_data, x='Exited', y='Tenure', hue='Exited', ax=ax[1][2])
plt.show()

# %% [markdown]
# - **Credit Score**: Customers who exited the service tend to have a slightly lower median credit score compared to those who stayed. This suggests that credit score might play a role in customer retention.
# - **Age**: The age distribution shows that older customers have a higher tendency to churn, as indicated by the higher median age of customers who exited.
# - **Balance**: There is a noticeable difference in balance distribution, with those who exited having a higher median balance. This could indicate that customers with higher balances are more likely to leave, possibly due to dissatisfaction despite having significant funds.
# - **Estimated Salary**: There is no significant difference in estimated salary between those who exited and those who did not, suggesting that salary might not be a strong predictor of churn in this dataset.
# - **NumOfProducts**: Customers with fewer products (1 product) are more likely to churn, as shown by the lower median for those who exited. This indicates that customers with a higher engagement (more products) are less likely to churn.
# - **Tenure**: The tenure distribution shows no significant difference between the two groups, indicating that the length of time a customer has been with the company might not be a strong indicator of churn.
#
# These visualizations help in identifying critical areas to focus on for improving customer retention strategies. By understanding these patterns, we can tailor our interventions more effectively to reduce churn.

# %% [markdown]
# ---

# %% [markdown]
# # Data Preparation
#
# In this section, we focus on preparing the dataset for model training and evaluation by separating it into training and testing subsets. This step is crucial for assessing the model's performance on unseen data and ensuring its generalizability.
#
# 1. **Categorical and Continuous Features**:
#    - The dataset includes both categorical and continuous features. Categorical features such as 'HasCrCard', 'IsActiveMember', 'Geography', and 'Gender' are discrete variables that classify data into specific categories.
#    - Continuous features, including 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', and 'EstimatedSalary', represent numerical values that can take on a range of values.
#
# 2. **Data Splitting**:
#    - The data is split into training and testing subsets using a 75-25 split ratio. This ensures that 75% of the data is used for training the model, while the remaining 25% is reserved for testing the model's performance.
#    - The splitting is performed with a fixed random state (100) to ensure reproducibility of results.
#
# 3. **Feature Selection**:
#    - The training data is constructed by combining the target variable 'Exited' with both continuous and categorical features. This comprehensive selection ensures that the model is exposed to all relevant information for making accurate predictions.
#
# By carefully preparing the data in this manner, we set a strong foundation for building robust machine learning models that can effectively predict customer churn.

# %%
# Separating into trainning and testing data
categorical = ['HasCrCard', 'IsActiveMember','Geography', 'Gender']
continuous = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary']

train = churn_data.sample(frac=0.8, random_state=100)
test = churn_data.drop(train.index)
train = train[['Exited'] + continuous + categorical]
train.head()
# Out:
#      Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 3348      0          825   40       6  132308.22              1
# 2214      0          850   26       4   62610.96              2
# 1681      0          681   32       3       0.00              2
# 4144      0          655   44       8   87471.63              1
# 4076      1          672   50       1       0.00              1
#
#       EstimatedSalary  HasCrCard  IsActiveMember Geography  Gender
# 3348        117122.50          0               0    France    Male
# 2214        179365.10          0               1    France  Female
# 1681         59679.90          1               1     Spain  Female
# 4144        188593.98          0               1    France    Male
# 4076         12106.82          1               0    France  Female

# %% [markdown]
# #### Encoding Categorical Variables
#
# Categorical variables must be encoded into numerical values to be processed by machine learning algorithms. We use Label Encoding to transform these variables. Label Encoding assigns a unique integer to each category of the variable, which, although not maintaining any ordinal relationship, allows for the inclusion of these categorical features in our models.
#
# 1. **Process**:
#    - **Initialization**: Create a `LabelEncoder` instance.
#    - **Transformation**: Encode each categorical variable, converting categories to numerical values.
#
# 2. **Application**:
#    - Apply the encoder to each categorical column.
#    - Ensure all categorical variables are now numerical, making the data suitable for machine learning.
#
# 3. **Verification**:
#    - Verify the transformed data by checking a subset, ensuring all categorical variables are numerically encoded.
#
# This step ensures compatibility with machine learning models, facilitating accurate and efficient model training.

# %%
# Encoding categorical variables using Label Encoder
le = LabelEncoder()
for column in categorical:
    churn_data[column] = le.fit_transform(churn_data[column])
    
train.head()
# Out:
#      Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 3348      0          825   40       6  132308.22              1
# 2214      0          850   26       4   62610.96              2
# 1681      0          681   32       3       0.00              2
# 4144      0          655   44       8   87471.63              1
# 4076      1          672   50       1       0.00              1
#
#       EstimatedSalary  HasCrCard  IsActiveMember Geography  Gender
# 3348        117122.50          0               0    France    Male
# 2214        179365.10          0               1    France  Female
# 1681         59679.90          1               1     Spain  Female
# 4144        188593.98          0               1    France    Male
# 4076         12106.82          1               0    France  Female

# %% [markdown]
# #### Normalizing Numerical Features
#
# Numerical features are often on different scales, which can bias a model towards variables with larger magnitudes. To prevent this, we apply StandardScaler to normalize these features, giving them equal weight in the predictive model.
#
# 1. **Process**:
#
#     - **Initialization**:
#         - Create a `StandardScaler` instance.
#
#     - **Transformation**:
#         - Select numerical columns to scale: `['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']`.
#         - Apply the scaler to these columns, transforming them to a standard scale with a mean of 0 and a standard deviation of 1.
#
# 2. **Application**:
#
#     - Apply the scaler to each numerical column.
#     - Ensure all selected numerical variables are now on a comparable scale.
#
# 3. **Verification**:
#
#     - Verify the transformed data by checking a subset, ensuring all numerical variables are properly scaled.
#
# This step eliminates bias towards features with larger magnitudes, ensuring a balanced contribution from all features, which enhances the performance and accuracy of the predictive model.

# %%
# Standardizing numerical columns with StandardScaler
scaler = StandardScaler()
numerical_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
churn_data[numerical_columns] = scaler.fit_transform(churn_data[numerical_columns])

train.head()
# Out:
#      Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 3348      0          825   40       6  132308.22              1
# 2214      0          850   26       4   62610.96              2
# 1681      0          681   32       3       0.00              2
# 4144      0          655   44       8   87471.63              1
# 4076      1          672   50       1       0.00              1
#
#       EstimatedSalary  HasCrCard  IsActiveMember Geography  Gender
# 3348        117122.50          0               0    France    Male
# 2214        179365.10          0               1    France  Female
# 1681         59679.90          1               1     Spain  Female
# 4144        188593.98          0               1    France    Male
# 4076         12106.82          1               0    France  Female

# %% [markdown]
# ---

# %% [markdown]
# ### Machine Learning Training
#
# In this stage, we will train a diverse set of machine learning models on the dataset. Our aim is to evaluate and compare their performance using various metrics. By experimenting with different algorithms, we seek to identify the model that delivers the best predictive accuracy and f1 score. The models considered will encompass a range of methodologies, including decision trees, ensemble techniques, support vector machines, and neural networks, among others. The final step will involve a comprehensive comparison to determine the optimal model based on performance outcomes.

# %%
# Function to split data into training and testing sets
def get_data():
    # Select 80% of the data for training randomly
    train = churn_data.sample(frac=0.8, random_state=100)
    # Select the remaining data for testing
    test = churn_data.drop(train.index)
    return train, test

# Function to prepare data for modeling
def prepare_data(data):
    # Separate features (X) and target variable (y)
    X = data.drop('Exited', axis=1)
    y = data['Exited']
    return X, y

# Function to evaluate models using F1 score
def evaluate_models1(models, X, y):
    results = []
    algos = []
    
    for algo, model in models:
        # Define KFold cross-validation with 90 splits
        kfold = KFold(n_splits=90, random_state=30, shuffle=True)
        # Calculate F1 score for each model
        cv_score = cross_val_score(model, X, y, cv=kfold, scoring='f1')
        results.append(cv_score)
        algos.append(algo)
        
    return results, algos

# Function to evaluate models using accuracy score
def evaluate_models2(models, X, y):
    results = []
    algos = []
    
    for algo, model in models:
        # Define KFold cross-validation with 90 splits
        kfold = KFold(n_splits=90, random_state=30, shuffle=True)
        # Calculate accuracy score for each model
        cv_score = cross_val_score(model, X, y, cv=kfold, scoring='accuracy')
        results.append(cv_score)
        algos.append(algo)
        
    return results, algos

# Function to plot F1 score results
def plot_results1(results, algos):
    colors = ['skyblue']
    plt.figure(figsize=(10,10))
    # Create boxplot for F1 scores
    box = plt.boxplot(results, labels=algos, patch_artist=True)
    plt.title('Algorithm F1 Score Comparison')
    plt.xlabel('Algorithm')
    plt.ylabel('F1 score')
    plt.xticks(rotation=90)

    # Set colors for the boxes
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)

    plt.show()

# Function to plot accuracy score results
def plot_results2(results, algos):
    colors = ['skyblue']
    plt.figure(figsize=(10,10))
    # Create boxplot for accuracy scores
    box = plt.boxplot(results, labels=algos, patch_artist=True)
    plt.title('Algorithm Accuracy Comparison')
    plt.xlabel('Algorithm')
    plt.ylabel('Accuracy')
    plt.xticks(rotation=90)

    # Set colors for the boxes
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)

    plt.show()
    
# Function to find the best models based on F1 score and accuracy
def best_models():
    # Get training and testing data
    train, _ = get_data()
    X_train, y_train = prepare_data(train)
    
    # Define a list of models to evaluate
    models = [
        ('SVM', SVC()),
        ('Logistic Regression', LogisticRegression()),
        ('Decision Tree', DecisionTreeClassifier()),
        ('Extra Trees', ExtraTreesClassifier()),
        ('Quadratic Discriminant Analysis', QuadraticDiscriminantAnalysis()),
        ('CatBoost', CatBoostClassifier(logging_level='Silent', random_state=30)),
        ('Random Forest', RandomForestClassifier()),  
        ('Linear Discriminant Analysis', LinearDiscriminantAnalysis()),       
        ('MLP', MLPClassifier(max_iter=1000)), 
        ('KNN', KNeighborsClassifier()),
        ('Naive Bayes', GaussianNB()),
        ('AdaBoost', AdaBoostClassifier()),
        ('Bagging', BaggingClassifier()),
        ('Gradient Boosting', GradientBoostingClassifier()),
        ('XGBoost', XGBClassifier()),
    ]

    # Evaluate models using F1 score and accuracy
    results1, algos1 = evaluate_models1(models, X_train, y_train)
    results2, algos2 = evaluate_models2(models, X_train, y_train)
    
    # Plot results
    plot_results1(results1, algos1)
    plot_results2(results2, algos2)

# Call the function to find and plot the best models
best_models()

# %% [markdown]
# #### Analysis of Model Performance
#
# ##### Evaluation Metrics:
#
# - **F1 Score:** The F1 score is a measure of a test's accuracy, considering both the precision and the recall to compute the score. The F1 score is especially useful when the class distribution is imbalanced.
# - **Accuracy:** Accuracy is the ratio of correctly predicted instances to the total instances. It is a simple yet widely used metric for classification tasks.
#
# ##### Results Interpretation:
#
# - **Support Vector Machine (SVM):** Exhibited consistent performance with relatively high F1 scores and accuracy, indicating its robustness in handling this dataset.
# - **Logistic Regression:** Showed competitive performance, particularly in F1 scores, suggesting its effectiveness in binary classification problems.
# - **Decision Tree:** While flexible, it showed a broader variance in performance, indicating sensitivity to data splits.
# - **Ensemble Methods (Random Forest, Gradient Boosting, AdaBoost):** These models generally performed well, leveraging multiple decision trees to improve predictive power and stability.
# - **CatBoost:** Displayed high performance with both F1 score and accuracy, benefiting from gradient boosting techniques optimized for categorical features.
# - **Neural Networks (MLP):** Showed potential but also displayed high variance, possibly due to sensitivity to hyperparameter settings and training dynamics.
#
# ##### Box Plots Analysis:
#
# - **F1 Score Comparison:**
#
#   The box plots reveal that CatBoost, Random Forest, and Gradient Boosting classifiers have narrower interquartile ranges and higher median F1 scores, indicating more reliable performance in predicting customer churn.
#
# - **Accuracy Comparison:**
#
#   Accuracy box plots indicate that ensemble methods like Random Forest and Gradient Boosting, along with SVM, consistently achieve high accuracy, confirming their suitability for this classification task.
#
# In conclusion, by evaluating multiple algorithms, we can select the best-performing model for predicting customer churn, ensuring robust and accurate predictions. The results highlight the effectiveness of ensemble methods and support vector machines in handling the given dataset.

# %% [markdown]
# ### Best model selection
#
# From the previous graphics we can notice that the best model was the CatBoost, having the best result in accurary and one of the best f1 score overall. This model was select taking in consideration that actual time that it took to execute too. Initially we had k-parts equal to ten (n_splits=10), but later we changed its value to 90 (recommend value in class theorical slides) which garanteed us better results due to the fact that our dataset was unbalanced. Now lets make another training with this model to get its best result.

# %%
# Prepare the training and testing data
train, test = get_data()
X_train, y_train = prepare_data(train)
X_test, y_test = prepare_data(test)

# Initialize and train the CatBoost model
model = CatBoostClassifier(logging_level='Silent', random_state=30, cat_features=['Geography', 'Gender'])
model.fit(X_train, y_train)

# Evaluate the model
print(f"Training Accuracy: {model.score(X_train, y_train)}")
print(f"Testing Accuracy: {model.score(X_test, y_test)}")

# Predict the test set
y_predicted = model.predict(X_test)

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_predicted, target_names=["Retained", "Exited"]))

# Plot the confusion matrix
confusion_matrix_res = confusion_matrix(y_test, y_predicted)
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_res, display_labels=["Retained", "Exited"]).plot()
plt.show()
# Out:
# Training Accuracy: 0.9046900540676475
# Testing Accuracy: 0.8667002012072434
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Retained       0.89      0.95      0.92      1615
#       Exited       0.70      0.50      0.59       373
#
#     accuracy                           0.87      1988
#    macro avg       0.80      0.73      0.75      1988
# weighted avg       0.86      0.87      0.86      1988

# %% [markdown]
# #### Detailed Steps and Results
#
# 1. **Prepare the Training and Testing Data:**
#    - We prepared the training and testing datasets by splitting the original dataset. The training data was used to fit the model, while the testing data was used to evaluate its performance.
#
# 2. **Initialize and Train the CatBoost Model:**
#    - The CatBoost model was initialized with a logging level set to 'Silent' and a random state for reproducibility. Categorical features such as 'Geography' and 'Gender' were specified to leverage CatBoost's ability to handle categorical data efficiently.
#
# 3. **Evaluate the Model:**
#    - The model was evaluated using both the training and testing datasets. The training accuracy was 90.47%, and the testing accuracy was 86.67%, demonstrating the model's generalizability and robustness.
#
# 4. **Predict the Test Set:**
#    - The model was used to predict the outcomes on the test set, which were then compared with the actual outcomes to assess performance.
#
# 5. **Print the Classification Report:**
#    - The classification report provided detailed metrics, including precision, recall, and F1 score for both classes ('Retained' and 'Exited'). The model performed well in predicting the 'Retained' class with an F1 score of 0.92. The performance for the 'Exited' class was lower, with an F1 score of 0.59.
#
# 6. **Plot the Confusion Matrix:**
#    - The confusion matrix displayed the number of correct and incorrect predictions for each class. Out of 1988 test instances, the model correctly predicted 1536 retained customers and 187 exited customers, with 79 false positives and 186 false negatives.
#
# #### Model Performance Metrics
#
# - **Training Accuracy:** 90.47%
# - **Testing Accuracy:** 86.67%
# - **Confusion Matrix:**
#   - Retained: 1536 correct predictions, 79 false positives
#   - Exited: 187 correct predictions, 186 false negatives

# %% [markdown]
# ---

# %% [markdown]
# ![Alt Text](img/predict_churn.jpg)
#
# ### Conclusion
#
# This project developed a machine learning model to predict customer churn in the banking sector, employing comprehensive preprocessing, feature engineering, and model evaluation techniques.
#
# **Key Insights:**
# - **Significant Predictors:** Geography (higher churn in Germany), gender (higher among females), account activity (lower churn among active members), and product holding (higher churn with fewer products).
# - **Best Model:** The CatBoost classifier achieved a training accuracy of 90.47% and a testing accuracy of 86.67%, making it the most effective model for this task. Its robust handling of categorical features and high performance in both precision and recall metrics highlighted its suitability.
#
# **Model Performance:**
# - **Training Accuracy:** 90.47%
# - **Testing Accuracy:** 86.67%
# - **Confusion Matrix:**
#   - Retained: 1536 correct predictions, 79 false positives
#   - Exited: 187 correct predictions, 186 false negatives
#
# **Real-Life Applicability:**
# In real-world banking, this churn prediction model can be integrated into CRM systems to monitor and predict customer churn. By identifying high-risk customers, banks can implement personalized retention strategies, such as offering exclusive benefits, personalized financial advice, or targeted promotions. This proactive approach helps in reducing churn rates, enhancing overall customer satisfaction, and fostering long-term loyalty.
#
# This project demonstrates the value of machine learning in providing actionable insights for the banking industry, enabling proactive customer retention efforts and improved customer relationship management. The CatBoost model, with its exceptional performance and ability to handle categorical data, proved to be a powerful tool in predicting customer churn and supporting strategic decision-making in banking.
